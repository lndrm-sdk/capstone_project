# %% [markdown]
# Example of a notebook

# %%
print("hello world")

# %%
def print_even():
    for x in range(1, 10):
        if x % 2 == 0:
            print(x)
print_even()

# %%
def print_odd():
    for x in range(1, 10):
        if x % 2 != 0:
            print(x)
print_odd()
