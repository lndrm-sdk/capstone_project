# %%
# %sql

-- First create the catalogs

CREATE CATALOG governance_dev;
CREATE CATALOG governance_test;
CREATE CATALOG governance_prod;

# %%
# %sql

-- Create the schemas for governance_dev

CREATE SCHEMA IF NOT EXISTS governance_dev.bronze;
CREATE SCHEMA IF NOT EXISTS governance_dev.silver;
CREATE SCHEMA IF NOT EXISTS governance_dev.gold;
CREATE SCHEMA IF NOT EXISTS governance_dev.metadata;
CREATE SCHEMA IF NOT EXISTS governance_dev.monitoring;

# %%
# %sql

-- Create the schemas for governance_prod

CREATE SCHEMA IF NOT EXISTS governance_prod.bronze;
CREATE SCHEMA IF NOT EXISTS governance_prod.silver;
CREATE SCHEMA IF NOT EXISTS governance_prod.gold;
CREATE SCHEMA IF NOT EXISTS governance_prod.metadata;
CREATE SCHEMA IF NOT EXISTS governance_prod.monitoring;

# %%
# %sql

-- Create the schemas for governance_test

CREATE SCHEMA IF NOT EXISTS governance_test.bronze;
CREATE SCHEMA IF NOT EXISTS governance_test.silver;
CREATE SCHEMA IF NOT EXISTS governance_test.gold;
CREATE SCHEMA IF NOT EXISTS governance_test.metadata;
CREATE SCHEMA IF NOT EXISTS governance_test.monitoring;
