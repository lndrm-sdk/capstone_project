# %%
# %sql
CREATE CATALOG governance_dev;

# %%
# %sql
DESCRIBE CATALOG governance_dev;

# %%
# %sql
CREATE SCHEMA governance_dev.bronze;
CREATE SCHEMA governance_dev.metadata;

# %%
# %sql 
DESCRIBE DATABASE governance_dev.bronze
